# %% [markdown]
# # 🎮 Apuntes Python: Juego "Adivina el Número Random"
#
# ---
#
# # 🎯 Objetivo
#
# Crear un **juego en Python** donde:
#
# - El programa genera un **número aleatorio entre 1 y 100**
# - El usuario debe **adivinar el número**
# - El programa dará pistas:
#
# ⬆️ **Más alto**
# ⬇️ **Más bajo**
#
# El juego:
#
# - Cuenta los **intentos**
# - Permite **volver a jugar**
#
# ---
#
# # 📁 Estructura de la Carpeta
#
# El proyecto tiene dos archivos principales:
#
# - **numero-random.py** → Código del juego
# - **numero-random.md** → Apuntes y explicación paso a paso
#
# ---
#
# # 🪜 Pasos a seguir (resumen)
#
# 1️⃣ Generar un número aleatorio entre **1 y 100**
# 2️⃣ Pedir al usuario que ingrese un número
# 3️⃣ Comparar el número del usuario con el número secreto
# 4️⃣ Dar pistas: **“Más alto” o “Más bajo”**
# 5️⃣ Si acierta → felicitar al usuario
# 6️⃣ Contar el número de **intentos**
# 7️⃣ Preguntar si quiere **jugar otra partida**
#
# ---
#
# # 🔢 Variables necesarias
#
# | Variable | Función |
# |------|------|
# | `numero_secreto` | Guarda el número aleatorio generado |
# | `numero_usuario` | Número que introduce el jugador |
# | `intentos` | Contador de intentos |
# | `seguir_jugando` | Controla si el usuario quiere jugar otra partida |
#
# ---
#
# # 🧠 Pseudocódigo del programa
#
# El **pseudocódigo** describe los pasos antes de programar.
#
# ---
#
# ### 1️⃣ Importar librería random
#
# Necesaria para generar números aleatorios.
#
# ---
#
# ### 2️⃣ Mostrar mensaje de bienvenida
#
# Usamos `print()` para mostrar un mensaje al jugador.
#
# ---
#
# ### 3️⃣ Crear variable para controlar el juego
#
# seguir_jugando = "s"
#
#
# Esto permitirá **repetir el juego**.
#
# ---
#
# ### 4️⃣ Crear bucle principal
#
# Mientras el jugador quiera jugar:
#
# while seguir_jugando == "s"
#
#
# ---
#
# ### 5️⃣ Generar número secreto
#
# numero_secreto = random.randint(1,100)
#
#
# Esto genera un número aleatorio entre **1 y 100**.
#
# ---
#
# ### 6️⃣ Inicializar contador de intentos
#
# intentos = 0
#
#
# ---
#
# ### 7️⃣ Crear bucle interno
#
# Este bucle se repetirá **hasta que el jugador acierte**.
#
# while True
#
#
# ---
#
# ### 8️⃣ Pedir número al usuario
#
# numero_usuario = int(input())
#
#
# Se usa `int()` para convertir el texto a número.
#
# ---
#
# ### 9️⃣ Capturar errores de entrada
#
# Si el usuario escribe letras en vez de números.
#
# Se usa:
#
# try / except
#
#
# ---
#
# ### 🔟 Validar rango
#
# Comprobar que el número esté entre **1 y 100**.
#
# Si no lo está:
#
# - Mostrar mensaje
# - Pedir otro número
#
# ---
#
# ### 1️⃣1️⃣ Incrementar intentos
#
# intentos += 1
#
#
# Cada vez que el usuario prueba un número.
#
# ---
#
# ### 1️⃣2️⃣ Comparar números
#
# Si el número del jugador es:
#
# | Condición | Respuesta |
# |------|------|
# | Menor | ⬆️ "Más alto" |
# | Mayor | ⬇️ "Más bajo" |
# | Igual | 🎉 "Correcto" |
#
# Si acierta → salir del bucle con:
#
# break
#
#
# ---
#
# ### 1️⃣3️⃣ Preguntar si quiere jugar otra vez
#
# input("s/n")
#
#
# La respuesta se guarda en:
#
# seguir_jugando
#
#
# ---
#
# ### 1️⃣4️⃣ Terminar el juego
#
# Mostrar mensaje final:
#
# Gracias por jugar. ¡Hasta la próxima!
#
#
# ---
#
# # 💻 Código completo del juego
#
# 1. Importamos librería para números aleatorios
# import random
#
# 2. Mensaje de bienvenida
# print("🎮 Bienvenido/a a Adivina el número 🎮")
#
# 3. Variable para controlar si el jugador quiere repetir el juego
# seguir_jugando = "s"
#
# 4. Bucle principal: mientras el jugador quiera jugar
# while seguir_jugando == "s":
#
# # 5. Generar número secreto aleatorio entre 1 y 100
# numero_secreto = random.randint(1, 100)
#
# # 6. Inicializar contador de intentos
# intentos = 0
#
# # 7. Bucle hasta que el jugador adivine el número
# while True:
#
#     # 8. Intentar convertir input a número
#     try:
#
#         numero_usuario = int(input("Introduce un número entre 1 y 100: "))
#
#         # 9. Validar rango
#         if numero_usuario < 1 or numero_usuario > 100:
#             print("⚠️ El número debe estar entre 1 y 100")
#             continue
#
#         # 10. Contador de intentos
#         intentos += 1
#
#         # 11. Comparar número del jugador con el secreto
#         if numero_usuario < numero_secreto:
#             print("⬆️ Más alto")
#
#         elif numero_usuario > numero_secreto:
#             print("⬇️ Más bajo")
#
#         else:
#             print(f"🎉 ¡Correcto! Lo lograste en {intentos} intentos")
#             break
#
#     # 12. Captura error si no es número
#     except ValueError:
#         print("❌ Debes introducir un número válido")
#
# # 13. Preguntar si quiere jugar otra vez
# seguir_jugando = input("¿Quieres jugar otra vez? (s/n): ").lower()
# 14. Mensaje final
# print("Gracias por jugar. ¡Hasta la próxima!")
#
#
# ---
#
# # 🧩 Conceptos de Python utilizados
#
# | Concepto | Explicación |
# |------|------|
# | `import random` | Permite generar números aleatorios |
# | `print()` | Muestra mensajes al usuario |
# | `input()` | Recoge datos del usuario |
# | `while` | Bucle que repite acciones |
# | `try / except` | Captura errores para que el programa no se rompa |
# | `break` | Sale de un bucle |
# | `.lower()` | Convierte texto a minúsculas |
#
# ---
#
# # 🧠 Resumen del funcionamiento
#
# El programa genera un número secreto
# ↓
# El usuario introduce números
# ↓
# El programa da pistas (más alto / más bajo)
# ↓
# Cuenta los intentos
# ↓
# Si acierta → gana
# ↓
# Puede jugar otra partida
#
#
# ---
